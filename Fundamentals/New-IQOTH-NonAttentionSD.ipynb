# %%
import tensorflow as tf
import numpy as np
import cv2
import os
import numpy as np
import pandas as pd
import imageio
import random
import matplotlib.pyplot as plt
import keras
import tensorflow.keras as K

import tensorflow.keras.backend as Kback

from keras import layers
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import AveragePooling2D
from keras.layers import Dropout
from keras.layers import Conv2DTranspose
from keras.layers import concatenate
from keras.layers import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.callbacks import EarlyStopping
from keras.applications.resnet import ResNet50
from keras.applications import vgg16
from keras.applications import inception_v3
from keras.src.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.applications import DenseNet121, NASNetMobile, EfficientNetB0, Xception
from keras.layers import GlobalAveragePooling2D
from keras.applications.densenet import DenseNet121

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.utils.class_weight import compute_class_weight

from collections import Counter
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import roc_auc_score

# %%
from google.colab import drive
drive.mount('/content/drive')
with open('/content/drive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive/foo.txt
# Out:
# Mounted at /content/drive
# Hello Google Drive!

# %%
dataset="/content/drive/My Drive/LUNGCANCER/IQ-OTH/The IQ-OTHNCCD lung cancer dataset"

# %%
import os

dataset_folder_path = "/content/drive/My Drive/LUNGCANCER/IQ-OTH/The IQ-OTHNCCD lung cancer dataset"
folder_contents = os.listdir(dataset_folder_path)

# Filter out only the directories (folders)
folders = [item for item in folder_contents if os.path.isdir(os.path.join(dataset_folder_path, item))]

# Print the list of folders
print("Folders in the dataset:")
for folder in folders:
    print(folder)
# Out:
# Folders in the dataset:
# Normal cases
# Malignant cases
# Bengin cases

# %%
data_dir = "/content/drive/My Drive/LUNGCANCER/IQ-OTH/The IQ-OTHNCCD lung cancer dataset"
categories = ['Bengin cases', 'Malignant cases', 'Normal cases']

# %%
def preprocess_image(file_path):
    img = cv2.imread(file_path, 0)
    img = cv2.resize(img, (224, 224))
    img = cv2.cvtColor(img,cv2.COLOR_GRAY2RGB)
    img = img / 255.0
    return img

# %%
data = []
labels = []

for category in categories:
    path = os.path.join(data_dir, category)
    label = categories.index(category)
    for file in os.listdir(path):
        file_path = os.path.join(path, file)
        img = preprocess_image(file_path)
        data.append(img)
        labels.append(label)

# %%
data, labels = shuffle(data, labels, random_state=42)


print('Data length:', len(data))
print('labels counts:', Counter(labels))

X = np.array(data).reshape(-1, 224, 224, 3)
y = np.array(labels)
# Out:
# Data length: 1097
# labels counts: Counter({1: 561, 2: 416, 0: 120})

# %%
plt.imshow(X[y==2][2])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)


X_train, X_valid, y_train, y_valid=X_train, X_test, y_train, y_test





print('Train length:', len(X_train), X_train.shape)
print('Valid length:', len(X_valid), X_valid.shape)
train_datagen = ImageDataGenerator()
val_datagen = ImageDataGenerator()
# X,y valid are used for evaluate matrix






# X_train, X_valid, y_train, y_valid=X_train, X_test, y_train, y_test











print('Train length:', len(X_train), X_train.shape)
print('Valid length:', len(X_valid), X_valid.shape)

# train_generator = train_datagen.flow(X_fold, y_fold, batch_size=8, shuffle=True)
# validation_generator = val_datagen.flow(X_valid, y_valid, batch_size=8, shuffle=True)
# Out:
# Train length: 877 (877, 224, 224, 3)
# Valid length: 220 (220, 224, 224, 3)
# Train length: 877 (877, 224, 224, 3)
# Valid length: 220 (220, 224, 224, 3)

# %% [markdown]
# # **VGG 16**

# %%
base_model = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# We define the number of classes in the classification problem.
NUM_CLASSES = 3

# First, a sequential model is created, which will be used to build the VGG model.
vgg_model = Sequential()

# Se agrega una capa al modelo. base_model el modelo anteriormente preentrenado.
vgg_model.add(base_model)

# A flattening layer (Flatten) is added. This layer converts the output from the
# previous layer (which is likely a three-dimensional tensor) into a one-dimensional vector.
vgg_model.add(layers.Flatten())


# vgg_model.add(layers.Dropout(0.25))
vgg_model.add(layers.Dense(256, activation='relu'))
vgg_model.add(layers.Dense(128, activation='relu'))
vgg_model.add(layers.Dense(64, activation='relu'))
# A dense layer is added with NUM_CLASSES neurons and a sigmoid activation function.
# This layer produces the final output of the model.
vgg_model.add(layers.Dense(NUM_CLASSES, activation='softmax'))

# The first layer of the model (base_model) is frozen, so the weights of this layer
# will not be updated during training.
vgg_model.layers[0].trainable = False





vgg_model.summary()

optimizer=keras.optimizers.Adam(learning_rate=0.001)
losses=keras.losses.SparseCategoricalCrossentropy()
metrics=['accuracy']
vgg_model.compile(optimizer=optimizer,loss=losses,metrics=metrics)

epochs=20
batch_size=32
history= vgg_model.fit(X_train,y_train, epochs=20, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 256)               6422784
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 21178819 (80.79 MB)
# Trainable params: 6464131 (24.66 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
# Epoch 1/20
# 28/28 [==============================] - 28s 640ms/step - loss: 1.1557 - accuracy: 0.6534 - val_loss: 0.6353 - val_accuracy: 0.6818
# Epoch 2/20
# 28/28 [==============================] - 5s 168ms/step - loss: 0.2595 - accuracy: 0.9008 - val_loss: 0.3342 - val_accuracy: 0.8591
# Epoch 3/20
# 28/28 [==============================] - 5s 167ms/step - loss: 0.0980 - accuracy: 0.9761 - val_loss: 0.2445 - val_accuracy: 0.9091
# Epoch 4/20
# 28/28 [==============================] - 5s 175ms/step - loss: 0.0605 - accuracy: 0.9875 - val_loss: 0.1930 - val_accuracy: 0.9318
# Epoch 5/20
# 28/28 [==============================] - 5s 170ms/step - loss: 0.0272 - accuracy: 0.9966 - val_loss: 0.1489 - val_accuracy: 0.9500
# Epoch 6/20
# 28/28 [==============================] - 4s 153ms/step - loss: 0.0200 - accuracy: 0.9989 - val_loss: 0.1593 - val_accuracy: 0.9500
# Epoch 7/20
# 28/28 [==============================] - 5s 170ms/step - loss: 0.0145 - accuracy: 0.9989 - val_loss: 0.1128 - val_accuracy: 0.9636
# Epoch 8/20
# 28/28 [==============================] - 5s 169ms/step - loss: 0.0091 - accuracy: 0.9989 - val_loss: 0.1473 - val_accuracy: 0.9500
# Epoch 9/20
# 28/28 [==============================] - 4s 153ms/step - loss: 0.0307 - accuracy: 0.9920 - val_loss: 0.1298 - val_accuracy: 0.9591
# Epoch 10/20
# 28/28 [==============================] - 5s 173ms/step - loss: 0.0273 - accuracy: 0.9863 - val_loss: 0.2669 - val_accuracy: 0.9409
# Epoch 11/20
# 28/28 [==============================] - 5s 171ms/step - loss: 0.0170 - accuracy: 0.9966 - val_loss: 0.1780 - val_accuracy: 0.9409
# Epoch 12/20
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0120 - accuracy: 0.9977 - val_loss: 0.1611 - val_accuracy: 0.9636
# Epoch 13/20
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0088 - accuracy: 0.9989 - val_loss: 0.1008 - val_accuracy: 0.9727
# Epoch 14/20
# 28/28 [==============================] - 5s 175ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9591
# Epoch 15/20
# 28/28 [==============================] - 5s 172ms/step - loss: 8.7779e-04 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9636
# Epoch 16/20
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.2143 - val_accuracy: 0.9500
# Epoch 17/20
# 28/28 [==============================] - 4s 159ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.9773
# Epoch 18/20
# 28/28 [==============================] - 4s 158ms/step - loss: 0.0131 - accuracy: 0.9932 - val_loss: 0.0980 - val_accuracy: 0.9636
# Epoch 19/20
# 28/28 [==============================] - 4s 160ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9727
# Epoch 20/20
# 28/28 [==============================] - 4s 159ms/step - loss: 4.6961e-04 - accuracy: 1.0000 - val_loss: 0.1284 - val_accuracy: 0.9773

# %%
test_loss, test_accuracy = vgg_model.evaluate(X_valid,y_valid)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
y_pred = vgg_model.predict(X_valid, verbose=1)
y_pred_2 = np.argmax(y_pred, axis=1)

print(classification_report(y_valid, y_pred_2))
# Out:
# 7/7 [==============================] - 1s 126ms/step - loss: 0.1284 - accuracy: 0.9773
# Test Loss: 0.1284123808145523
# Test Accuracy: 0.9772727489471436
# 7/7 [==============================] - 1s 121ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95        30
#            1       0.97      1.00      0.99       117
#            2       0.97      0.97      0.97        73
#
#     accuracy                           0.98       220
#    macro avg       0.98      0.96      0.97       220
# weighted avg       0.98      0.98      0.98       220

# %%
cm= confusion_matrix(y_true=y_valid, y_pred=y_pred_2)
target_names = ["Benign", "Malignant", "Normal"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
disp.plot(cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label = 'Training Accuracy')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label = 'Training Loss')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
#One vs One
roc_auc_score(y_valid, y_pred,multi_class='ovo')
# Out:
# 0.9922771208159337

# %%
#One vs Rest
roc_auc_score(y_valid, y_pred,multi_class='ovr')
# Out:
# 0.9952533367109874

# %% [markdown]
# # **VGG 19**

# %%
base_model = VGG19(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# We define the number of classes in the classification problem.
NUM_CLASSES = 3

# First, a sequential model is created, which will be used to build the VGG model.
vgg_model = Sequential()

# Se agrega una capa al modelo. base_model el modelo anteriormente preentrenado.
vgg_model.add(base_model)

# A flattening layer (Flatten) is added. This layer converts the output from the
# previous layer (which is likely a three-dimensional tensor) into a one-dimensional vector.
vgg_model.add(layers.Flatten())


# vgg_model.add(layers.Dropout(0.25))
vgg_model.add(layers.Dense(256, activation='relu'))
vgg_model.add(layers.Dense(128, activation='relu'))
vgg_model.add(layers.Dense(64, activation='relu'))
# A dense layer is added with NUM_CLASSES neurons and a sigmoid activation function.
# This layer produces the final output of the model.
vgg_model.add(layers.Dense(NUM_CLASSES, activation='softmax'))

# The first layer of the model (base_model) is frozen, so the weights of this layer
# will not be updated during training.
vgg_model.layers[0].trainable = False





vgg_model.summary()

optimizer=keras.optimizers.Adam(learning_rate=0.001)
losses=keras.losses.SparseCategoricalCrossentropy()
metrics=['accuracy']
vgg_model.compile(optimizer=optimizer,loss=losses,metrics=metrics)

epochs=20
batch_size=32
history= vgg_model.fit(X_train,y_train, epochs=20, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_4 (Dense)             (None, 256)               6422784
#
#  dense_5 (Dense)             (None, 128)               32896
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 26488515 (101.05 MB)
# Trainable params: 6464131 (24.66 MB)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________
# Epoch 1/20
# 28/28 [==============================] - 8s 234ms/step - loss: 0.7892 - accuracy: 0.6819 - val_loss: 0.5105 - val_accuracy: 0.7909
# Epoch 2/20
# 28/28 [==============================] - 6s 203ms/step - loss: 0.3622 - accuracy: 0.8632 - val_loss: 0.2466 - val_accuracy: 0.9091
# Epoch 3/20
# 28/28 [==============================] - 6s 207ms/step - loss: 0.1391 - accuracy: 0.9544 - val_loss: 0.3304 - val_accuracy: 0.8773
# Epoch 4/20
# 28/28 [==============================] - 6s 209ms/step - loss: 0.0974 - accuracy: 0.9738 - val_loss: 0.2514 - val_accuracy: 0.9091
# Epoch 5/20
# 28/28 [==============================] - 6s 205ms/step - loss: 0.0771 - accuracy: 0.9726 - val_loss: 0.1705 - val_accuracy: 0.9545
# Epoch 6/20
# 28/28 [==============================] - 6s 206ms/step - loss: 0.1346 - accuracy: 0.9453 - val_loss: 0.2209 - val_accuracy: 0.9364
# Epoch 7/20
# 28/28 [==============================] - 6s 201ms/step - loss: 0.0569 - accuracy: 0.9886 - val_loss: 0.1649 - val_accuracy: 0.9591
# Epoch 8/20
# 28/28 [==============================] - 6s 201ms/step - loss: 0.0307 - accuracy: 0.9909 - val_loss: 0.1363 - val_accuracy: 0.9636
# Epoch 9/20
# 28/28 [==============================] - 6s 205ms/step - loss: 0.0120 - accuracy: 0.9989 - val_loss: 0.1100 - val_accuracy: 0.9682
# Epoch 10/20
# 28/28 [==============================] - 5s 193ms/step - loss: 0.0114 - accuracy: 0.9977 - val_loss: 0.1003 - val_accuracy: 0.9727
# Epoch 11/20
# 28/28 [==============================] - 5s 196ms/step - loss: 0.0074 - accuracy: 0.9989 - val_loss: 0.1263 - val_accuracy: 0.9682
# Epoch 12/20
# 28/28 [==============================] - 6s 199ms/step - loss: 0.0097 - accuracy: 0.9977 - val_loss: 0.1186 - val_accuracy: 0.9727
# Epoch 13/20
# 28/28 [==============================] - 6s 199ms/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.1938 - val_accuracy: 0.9591
# Epoch 14/20
# 28/28 [==============================] - 6s 209ms/step - loss: 0.0098 - accuracy: 0.9977 - val_loss: 0.1397 - val_accuracy: 0.9727
# Epoch 15/20
# 28/28 [==============================] - 6s 205ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.1507 - val_accuracy: 0.9455
# Epoch 16/20
# 28/28 [==============================] - 6s 206ms/step - loss: 0.0052 - accuracy: 0.9977 - val_loss: 0.1300 - val_accuracy: 0.9727
# Epoch 17/20
# 28/28 [==============================] - 5s 197ms/step - loss: 0.0073 - accuracy: 0.9954 - val_loss: 0.1788 - val_accuracy: 0.9682
# Epoch 18/20
# 28/28 [==============================] - 6s 202ms/step - loss: 0.0083 - accuracy: 0.9989 - val_loss: 0.1354 - val_accuracy: 0.9636
# Epoch 19/20
# 28/28 [==============================] - 6s 203ms/step - loss: 0.0124 - accuracy: 0.9977 - val_loss: 0.1292 - val_accuracy: 0.9636
# Epoch 20/20
# 28/28 [==============================] - 6s 205ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1597 - val_accuracy: 0.9682

# %%
test_loss, test_accuracy = vgg_model.evaluate(X_valid,y_valid)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
y_pred = vgg_model.predict(X_valid, verbose=1)
y_pred_2 = np.argmax(y_pred, axis=1)

print(classification_report(y_valid, y_pred_2))
# Out:
# 7/7 [==============================] - 1s 161ms/step - loss: 0.1597 - accuracy: 0.9682
# Test Loss: 0.1597195416688919
# Test Accuracy: 0.9681817889213562
# 7/7 [==============================] - 1s 153ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91        30
#            1       0.97      1.00      0.98       117
#            2       0.96      0.97      0.97        73
#
#     accuracy                           0.97       220
#    macro avg       0.98      0.94      0.95       220
# weighted avg       0.97      0.97      0.97       220

# %%
cm= confusion_matrix(y_true=y_valid, y_pred=y_pred_2)
target_names = ["Benign", "Malignant", "Normal"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
disp.plot(cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label = 'Training Accuracy')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label = 'Training Loss')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
#One vs One
roc_auc_score(y_valid, y_pred,multi_class='ovo')
# Out:
# 0.9903660773523787

# %%
#One vs Rest
roc_auc_score(y_valid, y_pred,multi_class='ovr')
# Out:
# 0.993974850127154

# %% [markdown]
# # **Inception V3**

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
base_model = InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# We define the number of classes in the classification problem.
NUM_CLASSES = 3

# First, a sequential model is created, which will be used to build the VGG model.
vgg_model = Sequential()

# Se agrega una capa al modelo. base_model el modelo anteriormente preentrenado.
vgg_model.add(base_model)

# A flattening layer (Flatten) is added. This layer converts the output from the
# previous layer (which is likely a three-dimensional tensor) into a one-dimensional vector.
vgg_model.add(layers.Flatten())


# vgg_model.add(layers.Dropout(0.25))
vgg_model.add(layers.Dense(256, activation='relu'))
vgg_model.add(layers.Dense(128, activation='relu'))
vgg_model.add(layers.Dense(64, activation='relu'))
# A dense layer is added with NUM_CLASSES neurons and a sigmoid activation function.
# This layer produces the final output of the model.
vgg_model.add(layers.Dense(NUM_CLASSES, activation='softmax'))

# The first layer of the model (base_model) is frozen, so the weights of this layer
# will not be updated during training.
vgg_model.layers[0].trainable = False





vgg_model.summary()

optimizer=keras.optimizers.Adam(learning_rate=0.001)
losses=keras.losses.SparseCategoricalCrossentropy()
metrics=['accuracy']
vgg_model.compile(optimizer=optimizer,loss=losses,metrics=metrics)

epochs=20
batch_size=32
history= vgg_model.fit(X_train,y_train, epochs=20, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  flatten_3 (Flatten)         (None, 51200)             0
#
#  dense_12 (Dense)            (None, 256)               13107456
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  dense_14 (Dense)            (None, 64)                8256
#
#  dense_15 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 34951587 (133.33 MB)
# Trainable params: 13148803 (50.16 MB)
# Non-trainable params: 21802784 (83.17 MB)
# _________________________________________________________________
# Epoch 1/20
# 28/28 [==============================] - 12s 209ms/step - loss: 6.8727 - accuracy: 0.6762 - val_loss: 0.7372 - val_accuracy: 0.8591
# Epoch 2/20
# 28/28 [==============================] - 3s 121ms/step - loss: 0.6254 - accuracy: 0.8712 - val_loss: 0.7415 - val_accuracy: 0.8182
# Epoch 3/20
# 28/28 [==============================] - 4s 127ms/step - loss: 0.2388 - accuracy: 0.9350 - val_loss: 0.2870 - val_accuracy: 0.9364
# Epoch 4/20
# 28/28 [==============================] - 3s 107ms/step - loss: 0.0645 - accuracy: 0.9738 - val_loss: 0.2327 - val_accuracy: 0.9273
# Epoch 5/20
# 28/28 [==============================] - 3s 97ms/step - loss: 0.0278 - accuracy: 0.9897 - val_loss: 0.2132 - val_accuracy: 0.9500
# Epoch 6/20
# 28/28 [==============================] - 3s 92ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2628 - val_accuracy: 0.9409
# Epoch 7/20
# 28/28 [==============================] - 3s 103ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.9500
# Epoch 8/20
# 28/28 [==============================] - 3s 110ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.2833 - val_accuracy: 0.9273
# Epoch 9/20
# 28/28 [==============================] - 3s 122ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1939 - val_accuracy: 0.9500
# Epoch 10/20
# 28/28 [==============================] - 3s 99ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2203 - val_accuracy: 0.9500
# Epoch 11/20
# 28/28 [==============================] - 3s 92ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2403 - val_accuracy: 0.9500
# Epoch 12/20
# 28/28 [==============================] - 3s 92ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2578 - val_accuracy: 0.9409
# Epoch 13/20
# 28/28 [==============================] - 3s 102ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2356 - val_accuracy: 0.9500
# Epoch 14/20
# 28/28 [==============================] - 3s 101ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2417 - val_accuracy: 0.9500
# Epoch 15/20
# 28/28 [==============================] - 3s 92ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2427 - val_accuracy: 0.9500
# Epoch 16/20
# 28/28 [==============================] - 3s 97ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2456 - val_accuracy: 0.9500
# Epoch 17/20
# 28/28 [==============================] - 3s 98ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2451 - val_accuracy: 0.9500
# Epoch 18/20
# 28/28 [==============================] - 3s 97ms/step - loss: 9.9255e-04 - accuracy: 1.0000 - val_loss: 0.2390 - val_accuracy: 0.9500
# Epoch 19/20
# 28/28 [==============================] - 3s 95ms/step - loss: 8.8956e-04 - accuracy: 1.0000 - val_loss: 0.2353 - val_accuracy: 0.9500
# Epoch 20/20
# 28/28 [==============================] - 3s 99ms/step - loss: 8.2638e-04 - accuracy: 1.0000 - val_loss: 0.2292 - val_accuracy: 0.9500

# %%
test_loss, test_accuracy = vgg_model.evaluate(X_valid,y_valid)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
y_pred = vgg_model.predict(X_valid, verbose=1)
y_pred_2 = np.argmax(y_pred, axis=1)

print(classification_report(y_valid, y_pred_2))
# Out:
# 7/7 [==============================] - 1s 90ms/step - loss: 0.2292 - accuracy: 0.9500
# Test Loss: 0.22920291125774384
# Test Accuracy: 0.949999988079071
# 7/7 [==============================] - 4s 83ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.73      0.85        30
#            1       0.97      1.00      0.98       117
#            2       0.91      0.96      0.93        73
#
#     accuracy                           0.95       220
#    macro avg       0.96      0.90      0.92       220
# weighted avg       0.95      0.95      0.95       220

# %%
cm= confusion_matrix(y_true=y_valid, y_pred=y_pred_2)
target_names = ["Benign", "Malignant", "Normal"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
disp.plot(cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label = 'Training Accuracy')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label = 'Training Loss')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
#One vs One
roc_auc_score(y_valid, y_pred,multi_class='ovo')
# Out:
# 0.9805266102069755

# %%
#One vs Rest
roc_auc_score(y_valid, y_pred,multi_class='ovr')
# Out:
# 0.9888673594539036

# %% [markdown]
# # **ResNet50**

# %%
base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# We define the number of classes in the classification problem.
NUM_CLASSES = 3

# First, a sequential model is created, which will be used to build the VGG model.
vgg_model = Sequential()

# Se agrega una capa al modelo. base_model el modelo anteriormente preentrenado.
vgg_model.add(base_model)

# A flattening layer (Flatten) is added. This layer converts the output from the
# previous layer (which is likely a three-dimensional tensor) into a one-dimensional vector.
vgg_model.add(layers.Flatten())


# vgg_model.add(layers.Dropout(0.25))
vgg_model.add(layers.Dense(256, activation='relu'))
vgg_model.add(layers.Dense(128, activation='relu'))
vgg_model.add(layers.Dense(64, activation='relu'))
# A dense layer is added with NUM_CLASSES neurons and a sigmoid activation function.
# This layer produces the final output of the model.
vgg_model.add(layers.Dense(NUM_CLASSES, activation='softmax'))

# The first layer of the model (base_model) is frozen, so the weights of this layer
# will not be updated during training.
vgg_model.layers[0].trainable = False





vgg_model.summary()

optimizer=keras.optimizers.Adam(learning_rate=0.001)
losses=keras.losses.SparseCategoricalCrossentropy()
metrics=['accuracy']
vgg_model.compile(optimizer=optimizer,loss=losses,metrics=metrics)

epochs=20
batch_size=32
history= vgg_model.fit(X_train,y_train, epochs=20, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_12 (Flatten)        (None, 100352)            0
#
#  dense_47 (Dense)            (None, 256)               25690368
#
#  dense_48 (Dense)            (None, 128)               32896
#
#  dense_49 (Dense)            (None, 64)                8256
#
#  dense_50 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 49319427 (188.14 MB)
# Trainable params: 25731715 (98.16 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________
# Epoch 1/20
# 28/28 [==============================] - 14s 291ms/step - loss: 2.0502 - accuracy: 0.5325 - val_loss: 0.7685 - val_accuracy: 0.6682
# Epoch 2/20
# 28/28 [==============================] - 3s 126ms/step - loss: 0.7396 - accuracy: 0.6944 - val_loss: 0.6889 - val_accuracy: 0.6864
# Epoch 3/20
# 28/28 [==============================] - 4s 130ms/step - loss: 0.6739 - accuracy: 0.7332 - val_loss: 0.5515 - val_accuracy: 0.7773
# Epoch 4/20
# 28/28 [==============================] - 4s 129ms/step - loss: 0.6515 - accuracy: 0.7320 - val_loss: 0.7541 - val_accuracy: 0.7000
# Epoch 5/20
# 28/28 [==============================] - 4s 127ms/step - loss: 0.5447 - accuracy: 0.7959 - val_loss: 0.3609 - val_accuracy: 0.8591
# Epoch 6/20
# 28/28 [==============================] - 4s 127ms/step - loss: 0.3482 - accuracy: 0.8814 - val_loss: 0.3527 - val_accuracy: 0.8682
# Epoch 7/20
# 28/28 [==============================] - 4s 152ms/step - loss: 0.2163 - accuracy: 0.9282 - val_loss: 0.2605 - val_accuracy: 0.9091
# Epoch 8/20
# 28/28 [==============================] - 4s 148ms/step - loss: 0.2341 - accuracy: 0.9145 - val_loss: 0.3255 - val_accuracy: 0.8727
# Epoch 9/20
# 28/28 [==============================] - 3s 126ms/step - loss: 0.1805 - accuracy: 0.9430 - val_loss: 0.2166 - val_accuracy: 0.9227
# Epoch 10/20
# 28/28 [==============================] - 4s 128ms/step - loss: 0.1797 - accuracy: 0.9384 - val_loss: 0.3199 - val_accuracy: 0.8727
# Epoch 11/20
# 28/28 [==============================] - 4s 130ms/step - loss: 0.1892 - accuracy: 0.9190 - val_loss: 0.1829 - val_accuracy: 0.9500
# Epoch 12/20
# 28/28 [==============================] - 4s 148ms/step - loss: 0.0929 - accuracy: 0.9715 - val_loss: 0.1789 - val_accuracy: 0.9455
# Epoch 13/20
# 28/28 [==============================] - 4s 148ms/step - loss: 0.0703 - accuracy: 0.9806 - val_loss: 0.1547 - val_accuracy: 0.9682
# Epoch 14/20
# 28/28 [==============================] - 4s 131ms/step - loss: 0.0602 - accuracy: 0.9886 - val_loss: 0.1372 - val_accuracy: 0.9682
# Epoch 15/20
# 28/28 [==============================] - 4s 147ms/step - loss: 0.0540 - accuracy: 0.9897 - val_loss: 0.1604 - val_accuracy: 0.9591
# Epoch 16/20
# 28/28 [==============================] - 4s 148ms/step - loss: 0.0432 - accuracy: 0.9966 - val_loss: 0.1736 - val_accuracy: 0.9636
# Epoch 17/20
# 28/28 [==============================] - 4s 149ms/step - loss: 0.0478 - accuracy: 0.9897 - val_loss: 0.3805 - val_accuracy: 0.8773
# Epoch 18/20
# 28/28 [==============================] - 4s 127ms/step - loss: 0.0569 - accuracy: 0.9840 - val_loss: 0.1566 - val_accuracy: 0.9682
# Epoch 19/20
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0242 - accuracy: 0.9989 - val_loss: 0.1507 - val_accuracy: 0.9682
# Epoch 20/20
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0254 - accuracy: 0.9966 - val_loss: 0.1199 - val_accuracy: 0.9682

# %%
test_loss, test_accuracy = vgg_model.evaluate(X_valid,y_valid)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
y_pred = vgg_model.predict(X_valid, verbose=1)
y_pred_2 = np.argmax(y_pred, axis=1)

print(classification_report(y_valid, y_pred_2))
# Out:
# 7/7 [==============================] - 1s 98ms/step - loss: 0.1199 - accuracy: 0.9682
# Test Loss: 0.11987956613302231
# Test Accuracy: 0.9681817889213562
# 7/7 [==============================] - 2s 101ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        30
#            1       0.97      1.00      0.99       117
#            2       0.97      0.93      0.95        73
#
#     accuracy                           0.97       220
#    macro avg       0.96      0.95      0.96       220
# weighted avg       0.97      0.97      0.97       220

# %%
cm= confusion_matrix(y_true=y_valid, y_pred=y_pred_2)
target_names = ["Benign", "Malignant", "Normal"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
disp.plot(cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label = 'Training Accuracy')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label = 'Training Loss')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
#One vs One
roc_auc_score(y_valid, y_pred,multi_class='ovo')
# Out:
# 0.9916344690317294

# %%
#One vs Rest
roc_auc_score(y_valid, y_pred,multi_class='ovr')
# Out:
# 0.9916811462451931

# %% [markdown]
# # **MobileNetV2**

# %%
base_model = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# We define the number of classes in the classification problem.
NUM_CLASSES = 3

# First, a sequential model is created, which will be used to build the VGG model.
vgg_model = Sequential()

# Se agrega una capa al modelo. base_model el modelo anteriormente preentrenado.
vgg_model.add(base_model)

# A flattening layer (Flatten) is added. This layer converts the output from the
# previous layer (which is likely a three-dimensional tensor) into a one-dimensional vector.
vgg_model.add(layers.Flatten())


# vgg_model.add(layers.Dropout(0.25))
vgg_model.add(layers.Dense(256, activation='relu'))
vgg_model.add(layers.Dense(128, activation='relu'))
vgg_model.add(layers.Dense(64, activation='relu'))
# A dense layer is added with NUM_CLASSES neurons and a sigmoid activation function.
# This layer produces the final output of the model.
vgg_model.add(layers.Dense(NUM_CLASSES, activation='softmax'))

# The first layer of the model (base_model) is frozen, so the weights of this layer
# will not be updated during training.
vgg_model.layers[0].trainable = False





vgg_model.summary()

optimizer=keras.optimizers.Adam(learning_rate=0.001)
losses=keras.losses.SparseCategoricalCrossentropy()
metrics=['accuracy']
vgg_model.compile(optimizer=optimizer,loss=losses,metrics=metrics)

epochs=20
batch_size=32
history= vgg_model.fit(X_train,y_train, epochs=20, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 7, 7, 1280)        2257984
#  tional)
#
#  flatten_11 (Flatten)        (None, 62720)             0
#
#  dense_43 (Dense)            (None, 256)               16056576
#
#  dense_44 (Dense)            (None, 128)               32896
#
#  dense_45 (Dense)            (None, 64)                8256
#
#  dense_46 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 18355907 (70.02 MB)
# Trainable params: 16097923 (61.41 MB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________
# Epoch 1/20
# 28/28 [==============================] - 9s 188ms/step - loss: 2.4217 - accuracy: 0.7708 - val_loss: 0.6511 - val_accuracy: 0.8409
# Epoch 2/20
# 28/28 [==============================] - 2s 58ms/step - loss: 0.2688 - accuracy: 0.9475 - val_loss: 0.3788 - val_accuracy: 0.9409
# Epoch 3/20
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0774 - accuracy: 0.9783 - val_loss: 0.3193 - val_accuracy: 0.9682
# Epoch 4/20
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0665 - accuracy: 0.9795 - val_loss: 0.6563 - val_accuracy: 0.9273
# Epoch 5/20
# 28/28 [==============================] - 2s 58ms/step - loss: 0.1782 - accuracy: 0.9669 - val_loss: 0.4587 - val_accuracy: 0.9636
# Epoch 6/20
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0073 - accuracy: 0.9989 - val_loss: 0.4553 - val_accuracy: 0.9500
# Epoch 7/20
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.3824 - val_accuracy: 0.9727
# Epoch 8/20
# 28/28 [==============================] - 2s 63ms/step - loss: 4.9877e-04 - accuracy: 1.0000 - val_loss: 0.3376 - val_accuracy: 0.9727
# Epoch 9/20
# 28/28 [==============================] - 2s 64ms/step - loss: 3.1853e-04 - accuracy: 1.0000 - val_loss: 0.3696 - val_accuracy: 0.9818
# Epoch 10/20
# 28/28 [==============================] - 2s 59ms/step - loss: 7.0614e-05 - accuracy: 1.0000 - val_loss: 0.4033 - val_accuracy: 0.9818
# Epoch 11/20
# 28/28 [==============================] - 2s 58ms/step - loss: 2.9000e-05 - accuracy: 1.0000 - val_loss: 0.3853 - val_accuracy: 0.9818
# Epoch 12/20
# 28/28 [==============================] - 2s 58ms/step - loss: 1.4397e-05 - accuracy: 1.0000 - val_loss: 0.3785 - val_accuracy: 0.9818
# Epoch 13/20
# 28/28 [==============================] - 2s 58ms/step - loss: 9.9956e-06 - accuracy: 1.0000 - val_loss: 0.3754 - val_accuracy: 0.9818
# Epoch 14/20
# 28/28 [==============================] - 2s 58ms/step - loss: 8.1765e-06 - accuracy: 1.0000 - val_loss: 0.3733 - val_accuracy: 0.9818
# Epoch 15/20
# 28/28 [==============================] - 2s 58ms/step - loss: 7.0041e-06 - accuracy: 1.0000 - val_loss: 0.3715 - val_accuracy: 0.9818
# Epoch 16/20
# 28/28 [==============================] - 2s 76ms/step - loss: 6.2237e-06 - accuracy: 1.0000 - val_loss: 0.3700 - val_accuracy: 0.9818
# Epoch 17/20
# 28/28 [==============================] - 2s 64ms/step - loss: 5.5742e-06 - accuracy: 1.0000 - val_loss: 0.3690 - val_accuracy: 0.9818
# Epoch 18/20
# 28/28 [==============================] - 2s 57ms/step - loss: 5.2404e-06 - accuracy: 1.0000 - val_loss: 0.3679 - val_accuracy: 0.9818
# Epoch 19/20
# 28/28 [==============================] - 2s 58ms/step - loss: 4.9092e-06 - accuracy: 1.0000 - val_loss: 0.3673 - val_accuracy: 0.9818
# Epoch 20/20
# 28/28 [==============================] - 2s 57ms/step - loss: 4.6838e-06 - accuracy: 1.0000 - val_loss: 0.3668 - val_accuracy: 0.9818

# %%
test_loss, test_accuracy = vgg_model.evaluate(X_valid,y_valid)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
y_pred = vgg_model.predict(X_valid, verbose=1)
y_pred_2 = np.argmax(y_pred, axis=1)

print(classification_report(y_valid, y_pred_2))
# Out:
# 7/7 [==============================] - 0s 47ms/step - loss: 0.3668 - accuracy: 0.9818
# Test Loss: 0.3668422996997833
# Test Accuracy: 0.9818181991577148
# 7/7 [==============================] - 1s 47ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93        30
#            1       0.99      1.00      1.00       117
#            2       0.96      1.00      0.98        73
#
#     accuracy                           0.98       220
#    macro avg       0.98      0.96      0.97       220
# weighted avg       0.98      0.98      0.98       220

# %%
cm= confusion_matrix(y_true=y_valid, y_pred=y_pred_2)
target_names = ["Benign", "Malignant", "Normal"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
disp.plot(cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label = 'Training Accuracy')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label = 'Training Loss')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
#One vs One
roc_auc_score(y_valid, y_pred,multi_class='ovo')
# Out:
# 0.9768681132836384

# %%
#One vs Rest
roc_auc_score(y_valid, y_pred,multi_class='ovr')
# Out:
# 0.9844981681831587

# %% [markdown]
# # **MobileNetV3 Large**

# %%
base_model= keras.applications.MobileNetV3Large(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# We define the number of classes in the classification problem.
NUM_CLASSES = 3

# First, a sequential model is created, which will be used to build the VGG model.
vgg_model = Sequential()

# Se agrega una capa al modelo. base_model el modelo anteriormente preentrenado.
vgg_model.add(base_model)

# A flattening layer (Flatten) is added. This layer converts the output from the
# previous layer (which is likely a three-dimensional tensor) into a one-dimensional vector.
vgg_model.add(layers.Flatten())


# vgg_model.add(layers.Dropout(0.25))
vgg_model.add(layers.Dense(256, activation='relu'))
vgg_model.add(layers.Dense(128, activation='relu'))
vgg_model.add(layers.Dense(64, activation='relu'))
# A dense layer is added with NUM_CLASSES neurons and a sigmoid activation function.
# This layer produces the final output of the model.
vgg_model.add(layers.Dense(NUM_CLASSES, activation='softmax'))

# The first layer of the model (base_model) is frozen, so the weights of this layer
# will not be updated during training.
vgg_model.layers[0].trainable = False





vgg_model.summary()

optimizer=keras.optimizers.Adam(learning_rate=0.001)
losses=keras.losses.SparseCategoricalCrossentropy()
metrics=['accuracy']
vgg_model.compile(optimizer=optimizer,loss=losses,metrics=metrics)

epochs=20
batch_size=32
history= vgg_model.fit(X_train,y_train, epochs=20, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 [==============================] - 0s 0us/step
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3large (Function  (None, 7, 7, 960)         2996352
#  al)
#
#  flatten_10 (Flatten)        (None, 47040)             0
#
#  dense_39 (Dense)            (None, 256)               12042496
#
#  dense_40 (Dense)            (None, 128)               32896
#
#  dense_41 (Dense)            (None, 64)                8256
#
#  dense_42 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 15080195 (57.53 MB)
# Trainable params: 12083843 (46.10 MB)
# Non-trainable params: 2996352 (11.43 MB)
# _________________________________________________________________
# Epoch 1/20
# 28/28 [==============================] - 11s 177ms/step - loss: 1.4646 - accuracy: 0.5188 - val_loss: 0.7444 - val_accuracy: 0.7364
# Epoch 2/20
# 28/28 [==============================] - 1s 53ms/step - loss: 0.6985 - accuracy: 0.7035 - val_loss: 0.5886 - val_accuracy: 0.7818
# Epoch 3/20
# 28/28 [==============================] - 2s 54ms/step - loss: 0.5615 - accuracy: 0.7811 - val_loss: 0.5294 - val_accuracy: 0.7727
# Epoch 4/20
# 28/28 [==============================] - 2s 54ms/step - loss: 0.4871 - accuracy: 0.8096 - val_loss: 0.4657 - val_accuracy: 0.8273
# Epoch 5/20
# 28/28 [==============================] - 2s 59ms/step - loss: 0.3817 - accuracy: 0.8643 - val_loss: 0.4848 - val_accuracy: 0.8273
# Epoch 6/20
# 28/28 [==============================] - 2s 58ms/step - loss: 0.3308 - accuracy: 0.8757 - val_loss: 0.5194 - val_accuracy: 0.7864
# Epoch 7/20
# 28/28 [==============================] - 2s 57ms/step - loss: 0.2512 - accuracy: 0.9099 - val_loss: 0.3961 - val_accuracy: 0.8864
# Epoch 8/20
# 28/28 [==============================] - 1s 53ms/step - loss: 0.2775 - accuracy: 0.8837 - val_loss: 0.2951 - val_accuracy: 0.9136
# Epoch 9/20
# 28/28 [==============================] - 1s 53ms/step - loss: 0.1841 - accuracy: 0.9396 - val_loss: 0.3896 - val_accuracy: 0.8409
# Epoch 10/20
# 28/28 [==============================] - 2s 55ms/step - loss: 0.3425 - accuracy: 0.8700 - val_loss: 0.4363 - val_accuracy: 0.8500
# Epoch 11/20
# 28/28 [==============================] - 1s 53ms/step - loss: 0.1956 - accuracy: 0.9202 - val_loss: 0.3909 - val_accuracy: 0.8636
# Epoch 12/20
# 28/28 [==============================] - 2s 55ms/step - loss: 0.1095 - accuracy: 0.9635 - val_loss: 0.2936 - val_accuracy: 0.8818
# Epoch 13/20
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0824 - accuracy: 0.9806 - val_loss: 0.2516 - val_accuracy: 0.9227
# Epoch 14/20
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0651 - accuracy: 0.9795 - val_loss: 0.3368 - val_accuracy: 0.8955
# Epoch 15/20
# 28/28 [==============================] - 2s 62ms/step - loss: 0.0718 - accuracy: 0.9818 - val_loss: 0.2362 - val_accuracy: 0.9227
# Epoch 16/20
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0418 - accuracy: 0.9932 - val_loss: 0.2374 - val_accuracy: 0.9227
# Epoch 17/20
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0877 - accuracy: 0.9726 - val_loss: 0.2161 - val_accuracy: 0.9318
# Epoch 18/20
# 28/28 [==============================] - 2s 60ms/step - loss: 0.0700 - accuracy: 0.9749 - val_loss: 0.2571 - val_accuracy: 0.9227
# Epoch 19/20
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0313 - accuracy: 0.9932 - val_loss: 0.2399 - val_accuracy: 0.9545
# Epoch 20/20
# 28/28 [==============================] - 1s 53ms/step - loss: 0.1352 - accuracy: 0.9521 - val_loss: 0.2992 - val_accuracy: 0.9136

# %%
test_loss, test_accuracy = vgg_model.evaluate(X_valid,y_valid)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
y_pred = vgg_model.predict(X_valid, verbose=1)
y_pred_2 = np.argmax(y_pred, axis=1)

print(classification_report(y_valid, y_pred_2))
# Out:
# 7/7 [==============================] - 0s 50ms/step - loss: 0.2992 - accuracy: 0.9136
# Test Loss: 0.2992141842842102
# Test Accuracy: 0.9136363863945007
# 7/7 [==============================] - 1s 36ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67        30
#            1       0.93      1.00      0.96       117
#            2       0.87      0.95      0.91        73
#
#     accuracy                           0.91       220
#    macro avg       0.93      0.82      0.85       220
# weighted avg       0.92      0.91      0.90       220

# %%
cm= confusion_matrix(y_true=y_valid, y_pred=y_pred_2)
target_names = ["Benign", "Malignant", "Normal"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
disp.plot(cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label = 'Training Accuracy')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label = 'Training Loss')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
#One vs One
roc_auc_score(y_valid, y_pred,multi_class='ovo')
# Out:
# 0.9769523475002927

# %%
#One vs Rest
roc_auc_score(y_valid, y_pred,multi_class='ovr')
# Out:
# 0.9840637888613394

# %% [markdown]
# # **MobileNetV3 Small**

# %%
base_model= keras.applications.MobileNetV3Small(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# We define the number of classes in the classification problem.
NUM_CLASSES = 3

# First, a sequential model is created, which will be used to build the VGG model.
vgg_model = Sequential()

# Se agrega una capa al modelo. base_model el modelo anteriormente preentrenado.
vgg_model.add(base_model)

# A flattening layer (Flatten) is added. This layer converts the output from the
# previous layer (which is likely a three-dimensional tensor) into a one-dimensional vector.
vgg_model.add(layers.Flatten())


# vgg_model.add(layers.Dropout(0.25))
vgg_model.add(layers.Dense(256, activation='relu'))
vgg_model.add(layers.Dense(128, activation='relu'))
vgg_model.add(layers.Dense(64, activation='relu'))
# A dense layer is added with NUM_CLASSES neurons and a sigmoid activation function.
# This layer produces the final output of the model.
vgg_model.add(layers.Dense(NUM_CLASSES, activation='softmax'))

# The first layer of the model (base_model) is frozen, so the weights of this layer
# will not be updated during training.
vgg_model.layers[0].trainable = False





vgg_model.summary()

optimizer=keras.optimizers.Adam(learning_rate=0.001)
losses=keras.losses.SparseCategoricalCrossentropy()
metrics=['accuracy']
vgg_model.compile(optimizer=optimizer,loss=losses,metrics=metrics)

epochs=20
batch_size=32
history= vgg_model.fit(X_train,y_train, epochs=20, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 [==============================] - 0s 0us/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3small (Function  (None, 7, 7, 576)         939120
#  al)
#
#  flatten_4 (Flatten)         (None, 28224)             0
#
#  dense_16 (Dense)            (None, 256)               7225600
#
#  dense_17 (Dense)            (None, 128)               32896
#
#  dense_18 (Dense)            (None, 64)                8256
#
#  dense_19 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 8206067 (31.30 MB)
# Trainable params: 7266947 (27.72 MB)
# Non-trainable params: 939120 (3.58 MB)
# _________________________________________________________________
# Epoch 1/20
# 28/28 [==============================] - 10s 171ms/step - loss: 1.3238 - accuracy: 0.5245 - val_loss: 1.2458 - val_accuracy: 0.6455
# Epoch 2/20
# 28/28 [==============================] - 1s 40ms/step - loss: 0.8825 - accuracy: 0.6705 - val_loss: 0.9013 - val_accuracy: 0.5455
# Epoch 3/20
# 28/28 [==============================] - 1s 35ms/step - loss: 0.7785 - accuracy: 0.6830 - val_loss: 0.8964 - val_accuracy: 0.6000
# Epoch 4/20
# 28/28 [==============================] - 1s 35ms/step - loss: 0.7951 - accuracy: 0.6591 - val_loss: 0.7958 - val_accuracy: 0.6682
# Epoch 5/20
# 28/28 [==============================] - 1s 34ms/step - loss: 0.6800 - accuracy: 0.7263 - val_loss: 0.7259 - val_accuracy: 0.7000
# Epoch 6/20
# 28/28 [==============================] - 1s 32ms/step - loss: 0.6976 - accuracy: 0.7355 - val_loss: 0.8350 - val_accuracy: 0.6455
# Epoch 7/20
# 28/28 [==============================] - 1s 37ms/step - loss: 0.7107 - accuracy: 0.7058 - val_loss: 0.8441 - val_accuracy: 0.5864
# Epoch 8/20
# 28/28 [==============================] - 1s 33ms/step - loss: 0.6289 - accuracy: 0.7640 - val_loss: 0.6455 - val_accuracy: 0.7182
# Epoch 9/20
# 28/28 [==============================] - 1s 33ms/step - loss: 0.6115 - accuracy: 0.7742 - val_loss: 0.8004 - val_accuracy: 0.7409
# Epoch 10/20
# 28/28 [==============================] - 1s 46ms/step - loss: 0.5796 - accuracy: 0.7856 - val_loss: 0.7034 - val_accuracy: 0.6818
# Epoch 11/20
# 28/28 [==============================] - 1s 41ms/step - loss: 0.5934 - accuracy: 0.7674 - val_loss: 0.6378 - val_accuracy: 0.7364
# Epoch 12/20
# 28/28 [==============================] - 1s 46ms/step - loss: 0.5376 - accuracy: 0.7834 - val_loss: 0.7004 - val_accuracy: 0.7091
# Epoch 13/20
# 28/28 [==============================] - 1s 35ms/step - loss: 0.5506 - accuracy: 0.7879 - val_loss: 0.6302 - val_accuracy: 0.7500
# Epoch 14/20
# 28/28 [==============================] - 1s 38ms/step - loss: 0.5260 - accuracy: 0.7879 - val_loss: 0.6162 - val_accuracy: 0.7773
# Epoch 15/20
# 28/28 [==============================] - 1s 38ms/step - loss: 0.5048 - accuracy: 0.7993 - val_loss: 0.5815 - val_accuracy: 0.7864
# Epoch 16/20
# 28/28 [==============================] - 1s 40ms/step - loss: 0.4723 - accuracy: 0.8050 - val_loss: 0.5839 - val_accuracy: 0.7727
# Epoch 17/20
# 28/28 [==============================] - 1s 40ms/step - loss: 0.4913 - accuracy: 0.7913 - val_loss: 0.6496 - val_accuracy: 0.7364
# Epoch 18/20
# 28/28 [==============================] - 1s 38ms/step - loss: 0.5408 - accuracy: 0.7925 - val_loss: 0.8193 - val_accuracy: 0.7045
# Epoch 19/20
# 28/28 [==============================] - 1s 38ms/step - loss: 0.5646 - accuracy: 0.7651 - val_loss: 0.5838 - val_accuracy: 0.7500
# Epoch 20/20
# 28/28 [==============================] - 1s 32ms/step - loss: 0.5678 - accuracy: 0.7788 - val_loss: 0.5368 - val_accuracy: 0.7818

# %%
test_loss, test_accuracy = vgg_model.evaluate(X_valid,y_valid)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
y_pred = vgg_model.predict(X_valid, verbose=1)
y_pred_2 = np.argmax(y_pred, axis=1)

print(classification_report(y_valid, y_pred_2))
# Out:
# 7/7 [==============================] - 0s 32ms/step - loss: 0.5368 - accuracy: 0.7818
# Test Loss: 0.536839485168457
# Test Accuracy: 0.7818182110786438
# 7/7 [==============================] - 2s 36ms/step
#               precision    recall  f1-score   support
#
#            0       0.75      0.10      0.18        30
#            1       0.95      0.86      0.91       117
#            2       0.62      0.93      0.74        73
#
#     accuracy                           0.78       220
#    macro avg       0.77      0.63      0.61       220
# weighted avg       0.81      0.78      0.75       220

# %%
cm= confusion_matrix(y_true=y_valid, y_pred=y_pred_2)
target_names = ["Benign", "Malignant", "Normal"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
disp.plot(cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label = 'Training Accuracy')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label = 'Training Loss')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
#One vs One
roc_auc_score(y_valid, y_pred,multi_class='ovo')
# Out:
# 0.8873225877792087

# %%
#One vs Rest
roc_auc_score(y_valid, y_pred,multi_class='ovr')
# Out:
# 0.9207144687476019

# %% [markdown]
# # **AlexNet**

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, BatchNormalization

# Create the AlexNet model
alexnet_model = Sequential()

# 1st Convolutional Layer
alexnet_model.add(Conv2D(filters=96, input_shape=(224, 224, 3),
                 kernel_size=(11, 11), strides=(4, 4), padding='valid'))
alexnet_model.add(Activation('relu'))
alexnet_model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
alexnet_model.add(BatchNormalization())

# 2nd Convolutional Layer
alexnet_model.add(Conv2D(filters=256, kernel_size=(11, 11),
                 strides=(1, 1), padding='valid'))
alexnet_model.add(Activation('relu'))
alexnet_model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
alexnet_model.add(BatchNormalization())

# 3rd, 4th, and 5th Convolutional Layers
alexnet_model.add(Conv2D(filters=384, kernel_size=(3, 3), strides=(1, 1), padding='valid'))
alexnet_model.add(Activation('relu'))
alexnet_model.add(BatchNormalization())

alexnet_model.add(Conv2D(filters=384, kernel_size=(3, 3), strides=(1, 1), padding='valid'))
alexnet_model.add(Activation('relu'))
alexnet_model.add(BatchNormalization())

alexnet_model.add(Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding='valid'))
alexnet_model.add(Activation('relu'))
alexnet_model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))

# Fully Connected Layers
alexnet_model.add(Flatten())
alexnet_model.add(Dense(4096))
alexnet_model.add(Activation('relu'))
alexnet_model.add(Dropout(0.5))

alexnet_model.add(Dense(4096))
alexnet_model.add(Activation('relu'))
alexnet_model.add(Dropout(0.5))

# Output layer
alexnet_model.add(Dense(1000, activation='softmax'))  # Assuming 1000 classes for ImageNet

# Compile the model
alexnet_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# We define the number of classes in the classification problem.
NUM_CLASSES = 3

# First, a sequential model is created, which will be used to build the VGG model.
vgg_model = Sequential()

# Se agrega una capa al modelo. base_model el modelo anteriormente preentrenado.
vgg_model.add(alexnet_model)

# A flattening layer (Flatten) is added. This layer converts the output from the
# previous layer (which is likely a three-dimensional tensor) into a one-dimensional vector.
vgg_model.add(layers.Flatten())


# vgg_model.add(layers.Dropout(0.25))
vgg_model.add(layers.Dense(256, activation='relu'))
vgg_model.add(layers.Dense(128, activation='relu'))
vgg_model.add(layers.Dense(64, activation='relu'))
# A dense layer is added with NUM_CLASSES neurons and a sigmoid activation function.
# This layer produces the final output of the model.
vgg_model.add(layers.Dense(NUM_CLASSES, activation='softmax'))

# The first layer of the model (base_model) is frozen, so the weights of this layer
# will not be updated during training.
vgg_model.layers[0].trainable = False





vgg_model.summary()

optimizer=keras.optimizers.Adam(learning_rate=0.001)
losses=keras.losses.SparseCategoricalCrossentropy()
metrics=['accuracy']
vgg_model.compile(optimizer=optimizer,loss=losses,metrics=metrics)

epochs=20
batch_size=32
history= vgg_model.fit(X_train,y_train, epochs=20, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_5 (Sequential)   (None, 1000)              28041960
#
#  flatten_6 (Flatten)         (None, 1000)              0
#
#  dense_23 (Dense)            (None, 256)               256256
#
#  dense_24 (Dense)            (None, 128)               32896
#
#  dense_25 (Dense)            (None, 64)                8256
#
#  dense_26 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 28339563 (108.11 MB)
# Trainable params: 297603 (1.14 MB)
# Non-trainable params: 28041960 (106.97 MB)
# _________________________________________________________________
# Epoch 1/20
# 28/28 [==============================] - 12s 130ms/step - loss: 1.0341 - accuracy: 0.4926 - val_loss: 0.9737 - val_accuracy: 0.5318
# Epoch 2/20
# 28/28 [==============================] - 1s 26ms/step - loss: 0.9544 - accuracy: 0.5063 - val_loss: 0.9806 - val_accuracy: 0.5318
# Epoch 3/20
# 28/28 [==============================] - 1s 24ms/step - loss: 0.9477 - accuracy: 0.5063 - val_loss: 0.9865 - val_accuracy: 0.5318
# Epoch 4/20
# 28/28 [==============================] - 1s 24ms/step - loss: 0.9480 - accuracy: 0.5063 - val_loss: 0.9829 - val_accuracy: 0.5318
# Epoch 5/20
# 28/28 [==============================] - 1s 24ms/step - loss: 0.9490 - accuracy: 0.5063 - val_loss: 0.9811 - val_accuracy: 0.5318
# Epoch 6/20
# 28/28 [==============================] - 1s 24ms/step - loss: 0.9471 - accuracy: 0.5063 - val_loss: 0.9851 - val_accuracy: 0.5318
# Epoch 7/20
# 28/28 [==============================] - 1s 33ms/step - loss: 0.9481 - accuracy: 0.5063 - val_loss: 0.9880 - val_accuracy: 0.5318
# Epoch 8/20
# 28/28 [==============================] - 1s 35ms/step - loss: 0.9475 - accuracy: 0.5063 - val_loss: 0.9864 - val_accuracy: 0.5318
# Epoch 9/20
# 28/28 [==============================] - 1s 28ms/step - loss: 0.9495 - accuracy: 0.5063 - val_loss: 0.9862 - val_accuracy: 0.5318
# Epoch 10/20
# 28/28 [==============================] - 1s 29ms/step - loss: 0.9500 - accuracy: 0.5063 - val_loss: 0.9840 - val_accuracy: 0.5318
# Epoch 11/20
# 28/28 [==============================] - 1s 35ms/step - loss: 0.9487 - accuracy: 0.5063 - val_loss: 0.9842 - val_accuracy: 0.5318
# Epoch 12/20
# 28/28 [==============================] - 1s 24ms/step - loss: 0.9483 - accuracy: 0.5063 - val_loss: 0.9832 - val_accuracy: 0.5318
# Epoch 13/20
# 28/28 [==============================] - 1s 24ms/step - loss: 0.9504 - accuracy: 0.5063 - val_loss: 0.9915 - val_accuracy: 0.5318
# Epoch 14/20
# 28/28 [==============================] - 1s 24ms/step - loss: 0.9481 - accuracy: 0.5063 - val_loss: 0.9824 - val_accuracy: 0.5318
# Epoch 15/20
# 28/28 [==============================] - 1s 23ms/step - loss: 0.9471 - accuracy: 0.5063 - val_loss: 0.9835 - val_accuracy: 0.5318
# Epoch 16/20
# 28/28 [==============================] - 1s 24ms/step - loss: 0.9474 - accuracy: 0.5063 - val_loss: 0.9823 - val_accuracy: 0.5318
# Epoch 17/20
# 28/28 [==============================] - 1s 24ms/step - loss: 0.9471 - accuracy: 0.5063 - val_loss: 0.9858 - val_accuracy: 0.5318
# Epoch 18/20
# 28/28 [==============================] - 1s 25ms/step - loss: 0.9493 - accuracy: 0.5063 - val_loss: 0.9847 - val_accuracy: 0.5318
# Epoch 19/20
# 28/28 [==============================] - 1s 24ms/step - loss: 0.9468 - accuracy: 0.5063 - val_loss: 0.9837 - val_accuracy: 0.5318
# Epoch 20/20
# 28/28 [==============================] - 1s 23ms/step - loss: 0.9476 - accuracy: 0.5063 - val_loss: 0.9876 - val_accuracy: 0.5318

# %%
test_loss, test_accuracy = vgg_model.evaluate(X_valid,y_valid)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
y_pred = vgg_model.predict(X_valid, verbose=1)
y_pred_2 = np.argmax(y_pred, axis=1)

print(classification_report(y_valid, y_pred_2))
# Out:
# 7/7 [==============================] - 0s 22ms/step - loss: 0.9876 - accuracy: 0.5318
# Test Loss: 0.9875597953796387
# Test Accuracy: 0.5318182110786438
# 7/7 [==============================] - 0s 18ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.53      1.00      0.69       117
#            2       0.00      0.00      0.00        73
#
#     accuracy                           0.53       220
#    macro avg       0.18      0.33      0.23       220
# weighted avg       0.28      0.53      0.37       220
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm= confusion_matrix(y_true=y_valid, y_pred=y_pred_2)
target_names = ["Benign", "Malignant", "Normal"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
disp.plot(cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label = 'Training Accuracy')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label = 'Training Loss')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
#One vs One
roc_auc_score(y_valid, y_pred,multi_class='ovo')
# Out:
# 0.5326545811705629

# %%
#One vs Rest
roc_auc_score(y_valid, y_pred,multi_class='ovr')
# Out:
# 0.534329459765148

# %% [markdown]
# # **Densenet**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Conv2D, BatchNormalization, Activation, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications.densenet import DenseNet121

# Load the pre-trained DenseNet121 model (without top layers)
base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(224, 224, 3))

# We define the number of classes in the classification problem.
NUM_CLASSES = 3

# First, a sequential model is created, which will be used to build the VGG model.
vgg_model = Sequential()

# Se agrega una capa al modelo. base_model el modelo anteriormente preentrenado.
vgg_model.add(base_model)

# A flattening layer (Flatten) is added. This layer converts the output from the
# previous layer (which is likely a three-dimensional tensor) into a one-dimensional vector.
vgg_model.add(layers.Flatten())


# vgg_model.add(layers.Dropout(0.25))
vgg_model.add(layers.Dense(256, activation='relu'))
vgg_model.add(layers.Dense(128, activation='relu'))
vgg_model.add(layers.Dense(64, activation='relu'))
# A dense layer is added with NUM_CLASSES neurons and a sigmoid activation function.
# This layer produces the final output of the model.
vgg_model.add(layers.Dense(NUM_CLASSES, activation='softmax'))

# The first layer of the model (base_model) is frozen, so the weights of this layer
# will not be updated during training.
vgg_model.layers[0].trainable = False





vgg_model.summary()

optimizer=keras.optimizers.Adam(learning_rate=0.001)
losses=keras.losses.SparseCategoricalCrossentropy()
metrics=['accuracy']
vgg_model.compile(optimizer=optimizer,loss=losses,metrics=metrics)

epochs=20
batch_size=32
history= vgg_model.fit(X_train,y_train, epochs=20, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 7, 7, 1024)        7037504
#
#  flatten_7 (Flatten)         (None, 50176)             0
#
#  dense_27 (Dense)            (None, 256)               12845312
#
#  dense_28 (Dense)            (None, 128)               32896
#
#  dense_29 (Dense)            (None, 64)                8256
#
#  dense_30 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 19924163 (76.00 MB)
# Trainable params: 12886659 (49.16 MB)
# Non-trainable params: 7037504 (26.85 MB)
# _________________________________________________________________
# Epoch 1/20
# 28/28 [==============================] - 28s 508ms/step - loss: 3.7624 - accuracy: 0.6591 - val_loss: 0.4096 - val_accuracy: 0.8591
# Epoch 2/20
# 28/28 [==============================] - 4s 140ms/step - loss: 0.2994 - accuracy: 0.8997 - val_loss: 0.6605 - val_accuracy: 0.8682
# Epoch 3/20
# 28/28 [==============================] - 4s 140ms/step - loss: 0.0787 - accuracy: 0.9726 - val_loss: 0.1535 - val_accuracy: 0.9545
# Epoch 4/20
# 28/28 [==============================] - 4s 149ms/step - loss: 0.0627 - accuracy: 0.9806 - val_loss: 0.1765 - val_accuracy: 0.9636
# Epoch 5/20
# 28/28 [==============================] - 4s 153ms/step - loss: 0.0477 - accuracy: 0.9818 - val_loss: 0.1550 - val_accuracy: 0.9818
# Epoch 6/20
# 28/28 [==============================] - 3s 125ms/step - loss: 0.1725 - accuracy: 0.9544 - val_loss: 0.6160 - val_accuracy: 0.8409
# Epoch 7/20
# 28/28 [==============================] - 4s 141ms/step - loss: 0.1054 - accuracy: 0.9669 - val_loss: 0.2488 - val_accuracy: 0.9682
# Epoch 8/20
# 28/28 [==============================] - 3s 120ms/step - loss: 0.0101 - accuracy: 0.9943 - val_loss: 0.3788 - val_accuracy: 0.9455
# Epoch 9/20
# 28/28 [==============================] - 3s 119ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1961 - val_accuracy: 0.9818
# Epoch 10/20
# 28/28 [==============================] - 4s 127ms/step - loss: 8.7708e-04 - accuracy: 1.0000 - val_loss: 0.1926 - val_accuracy: 0.9818
# Epoch 11/20
# 28/28 [==============================] - 4s 140ms/step - loss: 2.7437e-04 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9818
# Epoch 12/20
# 28/28 [==============================] - 4s 129ms/step - loss: 2.0172e-04 - accuracy: 1.0000 - val_loss: 0.1945 - val_accuracy: 0.9818
# Epoch 13/20
# 28/28 [==============================] - 4s 127ms/step - loss: 1.9113e-04 - accuracy: 1.0000 - val_loss: 0.1954 - val_accuracy: 0.9818
# Epoch 14/20
# 28/28 [==============================] - 4s 130ms/step - loss: 1.6575e-04 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9818
# Epoch 15/20
# 28/28 [==============================] - 5s 179ms/step - loss: 1.6324e-04 - accuracy: 1.0000 - val_loss: 0.1993 - val_accuracy: 0.9818
# Epoch 16/20
# 28/28 [==============================] - 4s 158ms/step - loss: 1.5717e-04 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9818
# Epoch 17/20
# 28/28 [==============================] - 3s 122ms/step - loss: 1.5370e-04 - accuracy: 1.0000 - val_loss: 0.2031 - val_accuracy: 0.9818
# Epoch 18/20
# 28/28 [==============================] - 4s 146ms/step - loss: 1.3622e-04 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9818
# Epoch 19/20
# 28/28 [==============================] - 3s 123ms/step - loss: 1.3111e-04 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9818
# Epoch 20/20
# 28/28 [==============================] - 3s 119ms/step - loss: 1.2204e-04 - accuracy: 1.0000 - val_loss: 0.2076 - val_accuracy: 0.9818

# %%
test_loss, test_accuracy = vgg_model.evaluate(X_valid,y_valid)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
y_pred = vgg_model.predict(X_valid, verbose=1)
y_pred_2 = np.argmax(y_pred, axis=1)

print(classification_report(y_valid, y_pred_2))
# Out:
# 7/7 [==============================] - 1s 94ms/step - loss: 0.2076 - accuracy: 0.9818
# Test Loss: 0.2075621336698532
# Test Accuracy: 0.9818181991577148
# 7/7 [==============================] - 3s 104ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93        30
#            1       0.98      1.00      0.99       117
#            2       0.97      1.00      0.99        73
#
#     accuracy                           0.98       220
#    macro avg       0.99      0.96      0.97       220
# weighted avg       0.98      0.98      0.98       220

# %%
cm= confusion_matrix(y_true=y_valid, y_pred=y_pred_2)
target_names = ["Benign", "Malignant", "Normal"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
disp.plot(cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label = 'Training Accuracy')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label = 'Training Loss')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
#One vs One
roc_auc_score(y_valid, y_pred,multi_class='ovo')
# Out:
# 0.9878169353055197

# %%
#One vs Rest
roc_auc_score(y_valid, y_pred,multi_class='ovr')
# Out:
# 0.9921061775003218

# %% [markdown]
# # **Xception**

# %%
from tensorflow.keras.applications import Xception

# Create the Xception base model
base_model = Xception(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)


# We define the number of classes in the classification problem.
NUM_CLASSES = 3

# First, a sequential model is created, which will be used to build the VGG model.
vgg_model = Sequential()

# Se agrega una capa al modelo. base_model el modelo anteriormente preentrenado.
vgg_model.add(base_model)

# A flattening layer (Flatten) is added. This layer converts the output from the
# previous layer (which is likely a three-dimensional tensor) into a one-dimensional vector.
vgg_model.add(layers.Flatten())


# vgg_model.add(layers.Dropout(0.25))
vgg_model.add(layers.Dense(256, activation='relu'))
vgg_model.add(layers.Dense(128, activation='relu'))
vgg_model.add(layers.Dense(64, activation='relu'))
# A dense layer is added with NUM_CLASSES neurons and a sigmoid activation function.
# This layer produces the final output of the model.
vgg_model.add(layers.Dense(NUM_CLASSES, activation='softmax'))

# The first layer of the model (base_model) is frozen, so the weights of this layer
# will not be updated during training.
vgg_model.layers[0].trainable = False





vgg_model.summary()

optimizer=keras.optimizers.Adam(learning_rate=0.001)
losses=keras.losses.SparseCategoricalCrossentropy()
metrics=['accuracy']
vgg_model.compile(optimizer=optimizer,loss=losses,metrics=metrics)

epochs=20
batch_size=32
history= vgg_model.fit(X_train,y_train, epochs=20, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 1s 0us/step
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  flatten_8 (Flatten)         (None, 100352)            0
#
#  dense_31 (Dense)            (None, 256)               25690368
#
#  dense_32 (Dense)            (None, 128)               32896
#
#  dense_33 (Dense)            (None, 64)                8256
#
#  dense_34 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 46593195 (177.74 MB)
# Trainable params: 25731715 (98.16 MB)
# Non-trainable params: 20861480 (79.58 MB)
# _________________________________________________________________
# Epoch 1/20
# 28/28 [==============================] - 20s 438ms/step - loss: 3.9943 - accuracy: 0.7252 - val_loss: 1.4062 - val_accuracy: 0.8136
# Epoch 2/20
# 28/28 [==============================] - 5s 184ms/step - loss: 0.5949 - accuracy: 0.8837 - val_loss: 0.7759 - val_accuracy: 0.9091
# Epoch 3/20
# 28/28 [==============================] - 5s 168ms/step - loss: 0.1538 - accuracy: 0.9612 - val_loss: 0.3958 - val_accuracy: 0.9136
# Epoch 4/20
# 28/28 [==============================] - 5s 170ms/step - loss: 0.0695 - accuracy: 0.9783 - val_loss: 0.4168 - val_accuracy: 0.9364
# Epoch 5/20
# 28/28 [==============================] - 5s 169ms/step - loss: 0.0350 - accuracy: 0.9863 - val_loss: 0.3599 - val_accuracy: 0.9409
# Epoch 6/20
# 28/28 [==============================] - 5s 180ms/step - loss: 0.0178 - accuracy: 0.9943 - val_loss: 0.8281 - val_accuracy: 0.8864
# Epoch 7/20
# 28/28 [==============================] - 5s 164ms/step - loss: 0.0274 - accuracy: 0.9886 - val_loss: 0.5693 - val_accuracy: 0.9273
# Epoch 8/20
# 28/28 [==============================] - 5s 182ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.3824 - val_accuracy: 0.9409
# Epoch 9/20
# 28/28 [==============================] - 5s 178ms/step - loss: 0.0076 - accuracy: 0.9966 - val_loss: 0.1928 - val_accuracy: 0.9727
# Epoch 10/20
# 28/28 [==============================] - 5s 179ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2794 - val_accuracy: 0.9591
# Epoch 11/20
# 28/28 [==============================] - 5s 164ms/step - loss: 2.3989e-04 - accuracy: 1.0000 - val_loss: 0.1852 - val_accuracy: 0.9682
# Epoch 12/20
# 28/28 [==============================] - 5s 177ms/step - loss: 5.1742e-04 - accuracy: 1.0000 - val_loss: 0.2157 - val_accuracy: 0.9636
# Epoch 13/20
# 28/28 [==============================] - 5s 169ms/step - loss: 1.2554e-04 - accuracy: 1.0000 - val_loss: 0.2115 - val_accuracy: 0.9591
# Epoch 14/20
# 28/28 [==============================] - 5s 166ms/step - loss: 1.0641e-04 - accuracy: 1.0000 - val_loss: 0.2216 - val_accuracy: 0.9636
# Epoch 15/20
# 28/28 [==============================] - 5s 162ms/step - loss: 8.7454e-05 - accuracy: 1.0000 - val_loss: 0.2172 - val_accuracy: 0.9591
# Epoch 16/20
# 28/28 [==============================] - 5s 164ms/step - loss: 8.3301e-05 - accuracy: 1.0000 - val_loss: 0.2205 - val_accuracy: 0.9591
# Epoch 17/20
# 28/28 [==============================] - 5s 180ms/step - loss: 7.8286e-05 - accuracy: 1.0000 - val_loss: 0.2236 - val_accuracy: 0.9591
# Epoch 18/20
# 28/28 [==============================] - 5s 163ms/step - loss: 7.3072e-05 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9591
# Epoch 19/20
# 28/28 [==============================] - 5s 165ms/step - loss: 6.9666e-05 - accuracy: 1.0000 - val_loss: 0.2253 - val_accuracy: 0.9591
# Epoch 20/20
# 28/28 [==============================] - 5s 165ms/step - loss: 6.6418e-05 - accuracy: 1.0000 - val_loss: 0.2273 - val_accuracy: 0.9591

# %%
test_loss, test_accuracy = vgg_model.evaluate(X_valid,y_valid)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
y_pred = vgg_model.predict(X_valid, verbose=1)
y_pred_2 = np.argmax(y_pred, axis=1)

print(classification_report(y_valid, y_pred_2))
# Out:
# 7/7 [==============================] - 1s 124ms/step - loss: 0.2273 - accuracy: 0.9591
# Test Loss: 0.22729308903217316
# Test Accuracy: 0.9590908885002136
# 7/7 [==============================] - 2s 122ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.77      0.84        30
#            1       0.97      1.00      0.99       117
#            2       0.95      0.97      0.96        73
#
#     accuracy                           0.96       220
#    macro avg       0.95      0.91      0.93       220
# weighted avg       0.96      0.96      0.96       220

# %%
cm= confusion_matrix(y_true=y_valid, y_pred=y_pred_2)
target_names = ["Benign", "Malignant", "Normal"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
disp.plot(cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label = 'Training Accuracy')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label = 'Training Loss')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
#One vs One
roc_auc_score(y_valid, y_pred,multi_class='ovo')
# Out:
# 0.9837880029660852

# %%
#One vs Rest
roc_auc_score(y_valid, y_pred,multi_class='ovr')
# Out:
# 0.9894169524577903

# %% [markdown]
# # **EfficientNet50**

# %%
# Create the Xception base model

base_model = EfficientNetB0(input_shape = (224, 224, 3),
                         include_top = False,
                         weights = 'imagenet')


# We define the number of classes in the classification problem.
NUM_CLASSES = 3

# First, a sequential model is created, which will be used to build the VGG model.
vgg_model = Sequential()

# Se agrega una capa al modelo. base_model el modelo anteriormente preentrenado.
vgg_model.add(base_model)

# A flattening layer (Flatten) is added. This layer converts the output from the
# previous layer (which is likely a three-dimensional tensor) into a one-dimensional vector.
vgg_model.add(layers.Flatten())


# vgg_model.add(layers.Dropout(0.25))
vgg_model.add(layers.Dense(256, activation='relu'))
vgg_model.add(layers.Dense(128, activation='relu'))
vgg_model.add(layers.Dense(64, activation='relu'))
# A dense layer is added with NUM_CLASSES neurons and a sigmoid activation function.
# This layer produces the final output of the model.
vgg_model.add(layers.Dense(NUM_CLASSES, activation='softmax'))

# The first layer of the model (base_model) is frozen, so the weights of this layer
# will not be updated during training.
vgg_model.layers[0].trainable = False





vgg_model.summary()

optimizer=keras.optimizers.Adam(learning_rate=0.001)
losses=keras.losses.SparseCategoricalCrossentropy()
metrics=['accuracy']
vgg_model.compile(optimizer=optimizer,loss=losses,metrics=metrics)

epochs=20
batch_size=32
history= vgg_model.fit(X_train,y_train, epochs=20, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb0 (Functional  (None, 7, 7, 1280)        4049571
#  )
#
#  flatten_9 (Flatten)         (None, 62720)             0
#
#  dense_35 (Dense)            (None, 256)               16056576
#
#  dense_36 (Dense)            (None, 128)               32896
#
#  dense_37 (Dense)            (None, 64)                8256
#
#  dense_38 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 20147494 (76.86 MB)
# Trainable params: 16097923 (61.41 MB)
# Non-trainable params: 4049571 (15.45 MB)
# _________________________________________________________________
# Epoch 1/20
# 28/28 [==============================] - 18s 358ms/step - loss: 4.3147 - accuracy: 0.4185 - val_loss: 1.6913 - val_accuracy: 0.5318
# Epoch 2/20
# 28/28 [==============================] - 2s 84ms/step - loss: 1.4290 - accuracy: 0.3979 - val_loss: 1.3311 - val_accuracy: 0.3318
# Epoch 3/20
# 28/28 [==============================] - 2s 83ms/step - loss: 1.7263 - accuracy: 0.4527 - val_loss: 1.6651 - val_accuracy: 0.5318
# Epoch 4/20
# 28/28 [==============================] - 3s 90ms/step - loss: 1.3391 - accuracy: 0.4242 - val_loss: 1.0128 - val_accuracy: 0.5318
# Epoch 5/20
# 28/28 [==============================] - 3s 95ms/step - loss: 1.1582 - accuracy: 0.4504 - val_loss: 1.0599 - val_accuracy: 0.3318
# Epoch 6/20
# 28/28 [==============================] - 2s 84ms/step - loss: 1.0484 - accuracy: 0.4664 - val_loss: 0.9896 - val_accuracy: 0.5318
# Epoch 7/20
# 28/28 [==============================] - 3s 90ms/step - loss: 0.9968 - accuracy: 0.4778 - val_loss: 0.9760 - val_accuracy: 0.5318
# Epoch 8/20
# 28/28 [==============================] - 3s 92ms/step - loss: 0.9803 - accuracy: 0.4458 - val_loss: 1.3614 - val_accuracy: 0.5318
# Epoch 9/20
# 28/28 [==============================] - 2s 85ms/step - loss: 1.1262 - accuracy: 0.4470 - val_loss: 1.4319 - val_accuracy: 0.3318
# Epoch 10/20
# 28/28 [==============================] - 2s 88ms/step - loss: 1.2210 - accuracy: 0.4538 - val_loss: 1.2344 - val_accuracy: 0.3318
# Epoch 11/20
# 28/28 [==============================] - 3s 97ms/step - loss: 1.1767 - accuracy: 0.4538 - val_loss: 1.0039 - val_accuracy: 0.5318
# Epoch 12/20
# 28/28 [==============================] - 2s 84ms/step - loss: 1.0440 - accuracy: 0.4515 - val_loss: 1.0978 - val_accuracy: 0.5318
# Epoch 13/20
# 28/28 [==============================] - 2s 83ms/step - loss: 0.9939 - accuracy: 0.4823 - val_loss: 1.3583 - val_accuracy: 0.3318
# Epoch 14/20
# 28/28 [==============================] - 2s 90ms/step - loss: 0.9976 - accuracy: 0.4652 - val_loss: 0.9859 - val_accuracy: 0.5318
# Epoch 15/20
# 28/28 [==============================] - 2s 83ms/step - loss: 0.9593 - accuracy: 0.4892 - val_loss: 0.9990 - val_accuracy: 0.5318
# Epoch 16/20
# 28/28 [==============================] - 2s 87ms/step - loss: 0.9772 - accuracy: 0.4698 - val_loss: 1.0284 - val_accuracy: 0.3318
# Epoch 17/20
# 28/28 [==============================] - 2s 85ms/step - loss: 0.9968 - accuracy: 0.4424 - val_loss: 1.0484 - val_accuracy: 0.3318
# Epoch 18/20
# 28/28 [==============================] - 3s 91ms/step - loss: 0.9586 - accuracy: 0.5029 - val_loss: 1.0006 - val_accuracy: 0.5318
# Epoch 19/20
# 28/28 [==============================] - 3s 90ms/step - loss: 0.9636 - accuracy: 0.4778 - val_loss: 1.1010 - val_accuracy: 0.3318
# Epoch 20/20
# 28/28 [==============================] - 2s 82ms/step - loss: 0.9784 - accuracy: 0.4618 - val_loss: 0.9831 - val_accuracy: 0.5318

# %%
test_loss, test_accuracy = vgg_model.evaluate(X_valid,y_valid)
print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
y_pred = vgg_model.predict(X_valid, verbose=1)
y_pred_2 = np.argmax(y_pred, axis=1)

print(classification_report(y_valid, y_pred_2))
# Out:
# 7/7 [==============================] - 0s 62ms/step - loss: 0.9831 - accuracy: 0.5318
# Test Loss: 0.9830559492111206
# Test Accuracy: 0.5318182110786438
# 7/7 [==============================] - 3s 71ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.53      1.00      0.69       117
#            2       0.00      0.00      0.00        73
#
#     accuracy                           0.53       220
#    macro avg       0.18      0.33      0.23       220
# weighted avg       0.28      0.53      0.37       220
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm= confusion_matrix(y_true=y_valid, y_pred=y_pred_2)
target_names = ["Benign", "Malignant", "Normal"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
disp.plot(cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label = 'Training Accuracy')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label = 'Training Loss')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
#One vs One
roc_auc_score(y_valid, y_pred,multi_class='ovo')
# Out:
# 0.616448763480727

# %%
#One vs Rest
roc_auc_score(y_valid, y_pred,multi_class='ovr')
# Out:
# 0.6319647337938644
